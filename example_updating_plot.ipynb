# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1, 1, 1)

# %%
ax.set_xlabel('X')
ax.set_ylabel('Y');

# %%
ax.set_xlim(0,1)
ax.set_ylim(0,1);

# %%
ax.set_title('FIGURE A');

# %%
for i in range(10):    
    x = np.linspace(0,1,100)
    if ax.lines:
        for line in ax.lines:
            line.set_xdata(x)
            y = np.random.random(size=(100,1))
            line.set_ydata(y)
    else:
        y = np.random.random(size=(100,1))
        ax.plot(x, y, 'b')
    fig.canvas.draw()
    time.sleep(0.1)

# %%
if False:
    fig = plt.figure()
    num_steps = 100
    dx = 0.1
    dt = 0.01
    x_max = 50.0
    y_max = 2.0
    ax = fig.add_subplot(1,1,1)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_xlim(0,x_max)
    ax.set_ylim(-y_max,y_max)
    ax.set_title('Y=SIN(X)')
    for i in range(num_steps+1):
        x = np.arange(0, (x_max/num_steps)*i, dx)
        y = np.sin(x)
        if ax.lines:
            for line in ax.lines:
                line.set_xdata(x)
                line.set_ydata(y)
        else:
            ax.plot(x, y, 'g')
        fig.canvas.draw()
        time.sleep(dt)
