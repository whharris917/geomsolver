# %%
# %matplotlib notebook

# %%
import numpy as np
import IPython, torch, warnings
import geomsolver as gs
from line import OnPointsLine

# %%
warnings.simplefilter('ignore')

# %%
linkage = gs.Linkage() #show_origin=False)
# Out:
# <img src="data:image/png;base64,..." width="899.9999570846578">

# %%
A = linkage.add_anchorpoint(at=[0,0,0])
B = linkage.add_anchorpoint(at=[-2,0,0])
C = linkage.add_anchorpoint(at=[2,0,0])

# %%
bc = linkage.add_frompointsline(B, C)

# %%
D = linkage.add_anchorpoint(at=[0,2,0])
E = linkage.add_anchorpoint(at=[-2,2,0])
F = linkage.add_anchorpoint(at=[2,2,0])

# %%
ef = linkage.add_frompointsline(E, F)

# %%
G = bc.add_onlinepoint(alpha=0)

# %%
H = ef.add_onlinepoint(alpha=1)

# %%
gz = G.add_frompointline(L=2, theta=90)
gz.lock('theta')

# %%
zh = linkage.add_frompointsline(gz.p2, H)

# %%
H.lock()

# %%
gd = linkage.add_onpointsline(G, D, L=4, gamma=0)
gd.lock('gamma')

# %%
zh.constrain_length(0)
