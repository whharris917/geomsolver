# %%
# %matplotlib notebook

# %%
import numpy as np
import IPython, torch, warnings
import geomsolver as gs

# %%
warnings.simplefilter('ignore')

# %%
linkage = gs.Linkage()
# Out:
# <img src="data:image/png;base64,..." width="899.5555555555555">
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
A = linkage.add_anchorpoint(at=[2,0,0])

# %%
D = linkage.add_anchorpoint(at=[-2,0,0])

# %%
ab = A.add_frompointline(L=2, theta=0)

# %%
bc = ab.p2.add_frompointline(L=3, theta=135)

# %%
cd = linkage.add_frompointsline(bc.p2, D)

# %%
cd.constrain_length(L=4)

# %%
linkage.get_df()
# Out:
#             Type                              Geometry Parameter Name  \
# Full Name
# A          point   [Anchor]Point_A(at=[2.0, 0.0, 0.0])           None
# A.x        point   [Anchor]Point_A(at=[2.0, 0.0, 0.0])              x
# A.y        point   [Anchor]Point_A(at=[2.0, 0.0, 0.0])              y
# A.z        point   [Anchor]Point_A(at=[2.0, 0.0, 0.0])              z
# B          point  [Anchor]Point_B(at=[-2.0, 0.0, 0.0])           None
# B.x        point  [Anchor]Point_B(at=[-2.0, 0.0, 0.0])              x
# B.y        point  [Anchor]Point_B(at=[-2.0, 0.0, 0.0])              y
# B.z        point  [Anchor]Point_B(at=[-2.0, 0.0, 0.0])              z
# a           line     [FromPoint]Line_a(p1=a.1, p2=a.2)           None
# a.theta     line     [FromPoint]Line_a(p1=a.1, p2=a.2)          theta
# a.phi       line     [FromPoint]Line_a(p1=a.1, p2=a.2)            phi
# b           line     [FromPoint]Line_b(p1=b.1, p2=b.2)           None
# b.theta     line     [FromPoint]Line_b(p1=b.1, p2=b.2)          theta
# b.phi       line     [FromPoint]Line_b(p1=b.1, p2=b.2)            phi
# c           line    [FromPoints]Line_c(p1=c.1, p2=c.2)           None
#
#                                              Parameter Value Locked?  \
# Full Name
# A                                                       None    None
# A.x                                             tensor([2.])    True
# A.y                                             tensor([0.])    True
# A.z                                             tensor([0.])    True
# B                                                       None    None
# B.x                                            tensor([-2.])    True
# B.y                                             tensor([0.])    True
# B.z                                             tensor([0.])    True
# a                                                       None    None
# a.theta    Parameter containing:\ntensor([-0.0201], requi...   False
# a.phi                                       tensor([1.5708])    True
# b                                                       None    None
# b.theta    Parameter containing:\ntensor([2.4159], requir...   False
# b.phi                                       tensor([1.5708])    True
# c                                                       None    None
#
#           Constrained? Constraint Target  \
# Full Name
# A                 None              None
# A.x              False              None
# A.y              False              None
# A.z              False              None
# B                 None              None
# B.x              False              None
# B.y              False              None
# B.z              False              None
# a                 True              None
# a.theta          False              None
# a.phi            False              None
# b                 True              None
# b.theta          False              None
# b.phi            False              None
# c                 True                 4
#
#                                                Energy
# Full Name
# A                                                   0
# A.x                                                 0
# A.y                                                 0
# A.z                                                 0
# B                                                   0
# B.x                                                 0
# B.y                                                 0
# B.z                                                 0
# a                                                   0
# a.theta                                             0
# a.phi                                               0
# b                                                   0
# b.theta                                             0
# b.phi                                               0
# c          tensor(0.0537, grad_fn=<SqueezeBackward0>)

# %%
zz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 zz
#
# NameError: name 'zz' is not defined

# %%
ce = bc.p2.add_frompointline(L=4, theta=0)

# %%
ef = ce.p2.add_frompointline(L=3, theta=135)

# %%
fd = linkage.add_frompointsline(ef.p2, D)

# %%
fd.constrain_length(7)

# %%
linkage.get_df()

# %%
for i in range(100):
    ab.params.theta.constrain(target=10*i/100)

# %%
zz

# %%
bc = linkage.add_frompointsline(B, C)

# %%
de = A.add_onpointline(L=4, theta=50, beta=0.5)
de.params.beta.lock()

# %%
fg = A.add_onpointline(L=4, theta=100, beta=0.5)
fg.params.beta.lock()

# %%
H = de.add_onlinepoint(alpha=0.75)
H.lock()

# %%
J = fg.add_onlinepoint(alpha=0.75)
J.lock()

# %%
I = bc.add_onlinepoint(alpha=0.8)
I.lock()

# %%
K = de.add_onlinepoint(alpha=0.8)
K.lock()

# %%
hi = linkage.add_frompointsline(H, I)

# %%
jk = linkage.add_frompointsline(J, K)

# %%
en = linkage.add_onpointsline(L=4, parent1=de.p2, parent2=C, gamma=0)
en.lock()

# %%
nq = en.p2.add_frompointline(L=4, theta=-90, ux=en)
nq.lock()

# %%
hi.constrain_length(1)

# %%
jk.constrain_length(1)

# %%
#linkage.update()

# %%
#linkage.energy_plot.show_controller()

# %%
M = nq.add_onlinepoint(alpha=0.6)

# %%
lm = M.add_frompointline(L=4, theta=-90, ux=nq)
lm.lock()

# %%
_I = lm.add_onlinepoint(alpha=0.7)

# %%
_K = lm.add_onlinepoint(alpha=0.9)

# %%
ii = linkage.add_frompointsline(_I, I)

# %%
kk = linkage.add_frompointsline(_K, K)

# %%
I.unlock()

# %%
K.unlock()

# %%
ii.constrain_length(0)

# %%
kk.constrain_length(0)

# %%
"""
for i in range(1):
    de2en2.constrain_length(0)
    kk.constrain_length(0)
    ii.constrain_length(0)
"""

# %%
ef = de.p2.add_frompointline(L=1, theta=0)

# %%
G = bc.add_onlinepoint(alpha=0.9)
G.lock()

# %%
fg = linkage.add_frompointsline(ef.p2, G)

# %%
linkage.solve = False

# %%
zz

# %%
linkage.solve = True

# %%
fg.constrain_length(0)

# %%
ah = A.add_frompointline(L=0.5, theta=100)

# %%
hi = ah.p2.add_frompointline(L=0.5, theta=10)

# %%
J = de.add_onlinepoint(alpha=0.8)
J.lock()

# %%
ij = linkage.add_frompointsline(hi.p2, J)

# %%
#ij.constrain_length(0)

# %%
#linkage.create_controller(manual=True)
